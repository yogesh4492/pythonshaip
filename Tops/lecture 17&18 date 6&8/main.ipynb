# %%
"""
Date : 6 - 11-2025

What is Function ?
--------------------------
function is a block of code that are used again and again.
function which request code and whhwnwver we can call in program.

in python using of def keyword we can define function
- in python there is  no need o declare function we can direct define function usding def keyword.
--------------------------------------------------------------------------------------------

there is 2 types of function:
1: inbuild function
2) user defined function
-----------------------------------------------
1)inbuild function:
ex: print(),input(),len(),type()....
-----------------------------------------
function categories:
mainly 4 categories:
1) fuction with return type and with parameter
2) function with return type and with out parameter
3) fuction without return type and with parameter
4) function without returntype and without parameter
---------------------------------------------------------

2)
"""
# Out:
# '\nDate : 6 - 11-2025\n\n\n'
